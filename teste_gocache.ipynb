# %% [markdown]
# #### 1. Análise Exploratório dos Dados

# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
# Obter o diretório atual do notebook
diretorio_atual = os.getcwd()

# Concatenar o caminho para a pasta "dados"
caminho_pasta_dados = os.path.join(diretorio_atual, 'dados')

# %% [markdown]
# ##### Estatísticas Descritivas
#
# Vamos analisar estatísticas descritivas dos dados para entender melhor sua distribuição e identificar possíveis padrões anômalos.

# %%
# Carregar o arquivo sem ataque
dados_sem_ataque = pd.read_csv(caminho_pasta_dados + '\\arquivo_sem_ataque.csv')
dados_com_ataque = pd.read_csv(caminho_pasta_dados + '\\arquivo_com_ataque.csv')

# Exibir as primeiras linhas de cada dataframe para entender a estrutura dos dados
print("Dados sem ataque:")
display(dados_sem_ataque.head())

print("\nDados com ataque:")
display(dados_com_ataque.head())
# Out:
# Dados sem ataque:
#                       hora                                                 ip  \
# 0  2024-05-16 00:59:18 UTC  187.32.366c247c96033ea60b63de9679e7406ba1bf121...
# 1  2024-05-16 00:59:16 UTC  187.32.366c247c96033ea60b63de9679e7406ba1bf121...
# 2  2024-05-16 00:59:16 UTC  187.32.366c247c96033ea60b63de9679e7406ba1bf121...
# 3  2024-05-16 00:59:24 UTC  177.69.38967bbf070ce6a567f6807e59cf51e40d5406d...
# 4  2024-05-16 00:59:24 UTC  177.69.38967bbf070ce6a567f6807e59cf51e40d5406d...
#
#   metodo protocolo                                           hostname  \
# 0    GET  HTTP/2.0  868f83bf58d18987c37f666969d3fce065a63cd02ff5f0...
# 1    GET  HTTP/2.0  868f83bf58d18987c37f666969d3fce065a63cd02ff5f0...
# 2    GET  HTTP/2.0  868f83bf58d18987c37f666969d3fce065a63cd02ff5f0...
# 3    GET  HTTP/2.0  868f83bf58d18987c37f666969d3fce065a63cd02ff5f0...
# 4    GET  HTTP/2.0  868f83bf58d18987c37f666969d3fce065a63cd02ff5f0...
#
#                                                  uri  \
# 0  /d5cf542a066aa75b28c555079525899adfef349042a0c...
# 1  /d5cf542a066aa75b28c555079525899adfef349042a0c...
# 2  /d5cf542a066aa75b28c555079525899adfef349042a0c...
# 3  /d5cf542a066aa75b28c555079525899adfef349042a0c...
# 4  /d5cf542a066aa75b28c555079525899adfef349042a0c...
#
#                                          querystring  status_code  \
# 0  ?50148fa69f95e2a2bde55d4d27fd9d0611ada706e48d0...          302
# 1  ?9b70226ce15373c90996ed34173d7d0b3d2a299e2233d...          302
# 2  ?1e3c6f9eb16432ff4e2b7b71c013ebf48ce3389020ced...          302
# 3  ?50148fa69f95e2a2bde55d4d27fd9d0611ada706e48d0...          302
# 4  ?1e3c6f9eb16432ff4e2b7b71c013ebf48ce3389020ced...          302
#
#                                                  f0_  \
# 0  https://09e19ca6d8847d228ee144afc65d2cc9db8bde...
# 1  https://09e19ca6d8847d228ee144afc65d2cc9db8bde...
# 2  https://09e19ca6d8847d228ee144afc65d2cc9db8bde...
# 3  https://09e19ca6d8847d228ee144afc65d2cc9db8bde...
# 4  https://09e19ca6d8847d228ee144afc65d2cc9db8bde...
#
#                                            useragent  tamanho_request  \
# 0  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...              226
# 1  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...               90
# 2  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...              228
# 3  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             1237
# 4  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl...             1102
#
#    tamanho_resposta               organizacao pais                     cidade  \
# 0               0.0  AS16735 ALGAR TELECOM SA   BR       Aparecida de Goiania
# 1               0.0  AS16735 ALGAR TELECOM SA   BR       Aparecida de Goiania
# 2               0.0  AS16735 ALGAR TELECOM SA   BR       Aparecida de Goiania
# 3               0.0  AS16735 ALGAR TELECOM SA   BR  S\\xC3\\xA3o Bento do Sul
# 4               0.0  AS16735 ALGAR TELECOM SA   BR  S\\xC3\\xA3o Bento do Sul
#
#                                        cookie_sessao  \
# 0  ceeb03fee1e179adb77ea75e9817343927b9eb4c974794...
# 1  ceeb03fee1e179adb77ea75e9817343927b9eb4c974794...
# 2  ceeb03fee1e179adb77ea75e9817343927b9eb4c974794...
# 3  7ef80ba4187024a764159bb36381d5ddcd4955358a4023...
# 4  7ef80ba4187024a764159bb36381d5ddcd4955358a4023...
#
#                                         fingerprint1  \
# 0  2633728caa6baa2f9d75f5a27a0df167482910cd559a8f...
# 1  2633728caa6baa2f9d75f5a27a0df167482910cd559a8f...
# 2  2633728caa6baa2f9d75f5a27a0df167482910cd559a8f...
# 3  7a6b4cd932228469e512512d10c0ab4732371197a1268a...
# 4  7a6b4cd932228469e512512d10c0ab4732371197a1268a...
#
#                                         fingerprint2  \
# 0  0593bc1576221bf63db5d6ea7e096c02fb15923f819896...
# 1  0593bc1576221bf63db5d6ea7e096c02fb15923f819896...
# 2  0593bc1576221bf63db5d6ea7e096c02fb15923f819896...
# 3  1f333bf2dff13464aea663a63f9044deb36e230fbf89e8...
# 4  1f333bf2dff13464aea663a63f9044deb36e230fbf89e8...
#
#                                         fingerprint3
# 0  ad1f499e53e6325acdf7ad0759ef81b3442be7f0902e47...
# 1  ad1f499e53e6325acdf7ad0759ef81b3442be7f0902e47...
# 2  ad1f499e53e6325acdf7ad0759ef81b3442be7f0902e47...
# 3  aa653714fe1271a6b3c218605d90413225a63570fc7419...
# 4  aa653714fe1271a6b3c218605d90413225a63570fc7419...
# Dados com ataque:
#                       hora                                                 ip  \
# 0  2024-05-15 15:59:56 UTC  3.16.1a6931d1bd6093f2d7bd86a22fc657b9bba9a595b...
# 1  2024-05-15 15:59:33 UTC  177.91.6661493bb44e1df9a8bd020769c24a48a092a24...
# 2  2024-05-15 15:59:13 UTC  177.95.366c247c96033ea60b63de9679e7406ba1bf121...
# 3  2024-05-15 15:59:13 UTC  177.95.366c247c96033ea60b63de9679e7406ba1bf121...
# 4  2024-05-15 15:59:14 UTC  177.95.366c247c96033ea60b63de9679e7406ba1bf121...
#
#   metodo protocolo                                           hostname  \
# 0    GET  HTTP/2.0  cab18057667df4595131dbc97b20b663c54b070d23e4e1...
# 1    GET  HTTP/2.0  cab18057667df4595131dbc97b20b663c54b070d23e4e1...
# 2    GET  HTTP/2.0  cab18057667df4595131dbc97b20b663c54b070d23e4e1...
# 3    GET  HTTP/2.0  cab18057667df4595131dbc97b20b663c54b070d23e4e1...
# 4    GET  HTTP/2.0  cab18057667df4595131dbc97b20b663c54b070d23e4e1...
#
#                                                  uri  \
# 0  /f276ac316f69b3f71eda737633acf69638452b0aee48a...
# 1  /8a5edab282632443219e051e4ade2d1d5bbc671c78105...
# 2  /2c7f437a9bf6f7e32961284b70fa441969c5079c489b6...
# 3  /5d31f4d8c72923216e3cfd77b33991457650cce55b196...
# 4  /1119a502d8ba182b00c4bde713a20d3ddb846ec39e29d...
#
#                                          querystring  status_code  \
# 0                                                NaN          200
# 1                                                NaN          200
# 2                                                NaN          200
# 3                                                NaN          200
# 4  ?a074e1c1c7f2fdae1bb7bdf401d7b2c0fc4e0b19549d2...          200
#
#                                                  f0_  \
# 0                                                NaN
# 1                                                NaN
# 2  https://5bb4687e3bd3d2cff1f382bf68949ef0d5d007...
# 3  https://5bb4687e3bd3d2cff1f382bf68949ef0d5d007...
# 4  https://5bb4687e3bd3d2cff1f382bf68949ef0d5d007...
#
#                                            useragent  tamanho_request  \
# 0  Mozilla/5.0 (Macintosh; Intel Mac OS X 10_15_0...              196
# 1  Mozilla/5.0 (iPhone; CPU iPhone OS 17_4_1 like...              274
# 2  Mozilla/5.0 (iPhone; CPU iPhone OS 17_4 like M...               27
# 3  Mozilla/5.0 (iPhone; CPU iPhone OS 17_4 like M...               35
# 4  Mozilla/5.0 (iPhone; CPU iPhone OS 17_4 like M...               46
#
#    tamanho_resposta                                      organizacao pais  \
# 0               NaN                                AS16509 AMAZON-02   US
# 1               NaN  AS263432 CORPORATIVA TELECOMUNICACOES EIRELI ME   BR
# 2            1408.0                    AS27699 TELEFONICA BRASIL S.A   BR
# 3            2102.0                    AS27699 TELEFONICA BRASIL S.A   BR
# 4           53501.0                    AS27699 TELEFONICA BRASIL S.A   BR
#
#                cidade                                      cookie_sessao  \
# 0            Columbus  1e0a93baad5dd480f42d5b95a51be36c0f86543e36c689...
# 1             Barueri  4913706deec9c6962172970ddb26cec317abc6d2157887...
# 2  S\\xC3\\xA3o Paulo  9a619b8a0b6d46d36df93d0e379347119c812e1a6e8950...
# 3  S\\xC3\\xA3o Paulo  9a619b8a0b6d46d36df93d0e379347119c812e1a6e8950...
# 4  S\\xC3\\xA3o Paulo  04f93a511891dca068013e071a08e0a8832c1f803c9247...
#
#                                         fingerprint1  \
# 0  b2bcc0e205d8ecf9af803794fb0075443f770e6849ee67...
# 1  de928d0d6dff7b9793edb5c1522b6580b0b3e4ba0faff8...
# 2  de928d0d6dff7b9793edb5c1522b6580b0b3e4ba0faff8...
# 3  de928d0d6dff7b9793edb5c1522b6580b0b3e4ba0faff8...
# 4  de928d0d6dff7b9793edb5c1522b6580b0b3e4ba0faff8...
#
#                                         fingerprint2  \
# 0  844de68e6dea184cbfafec6f2dd46f1e82d3ff336b723a...
# 1  c523025a20e743aaee34dd69e3c92f9e505d2d2ab4fedb...
# 2  c523025a20e743aaee34dd69e3c92f9e505d2d2ab4fedb...
# 3  c523025a20e743aaee34dd69e3c92f9e505d2d2ab4fedb...
# 4  c523025a20e743aaee34dd69e3c92f9e505d2d2ab4fedb...
#
#                                         fingerprint3
# 0  16af3145e3eee586af1ab917de45236567be83c62d0e45...
# 1  d1ec27c5ea84f9aaa2fde750e00ed145404333f66a2431...
# 2  d1ec27c5ea84f9aaa2fde750e00ed145404333f66a2431...
# 3  d1ec27c5ea84f9aaa2fde750e00ed145404333f66a2431...
# 4  d1ec27c5ea84f9aaa2fde750e00ed145404333f66a2431...

# %%
# Estatísticas descritivas dos dados sem ataque
print("Estatísticas descritivas dos dados sem ataque:")
print(dados_sem_ataque.describe())

# Estatísticas descritivas dos dados com ataque
print("Estatísticas descritivas dos dados com ataque:")
print(dados_com_ataque.describe())
# Out:
# Estatísticas descritivas dos dados sem ataque:
#          status_code  tamanho_request  tamanho_resposta
# count  917527.000000     9.175270e+05      6.531850e+05
# mean      226.643290     5.528957e+03      5.032761e+04
# std        68.457838     9.138116e+04      2.393340e+05
# min       101.000000     7.000000e+00      0.000000e+00
# 25%       200.000000     7.400000e+01      1.450000e+02
# 50%       200.000000     1.610000e+02      4.084000e+03
# 75%       200.000000     5.340000e+02      3.083100e+04
# max       503.000000     7.952388e+07      8.703628e+07
# Estatísticas descritivas dos dados com ataque:
#          status_code  tamanho_request  tamanho_resposta
# count  348864.000000    348864.000000      2.560330e+05
# mean      213.450729      1048.825915      5.453435e+04
# std        57.608418     11088.762844      1.405912e+05
# min       200.000000        10.000000      0.000000e+00
# 25%       200.000000        45.000000      1.218000e+03
# 50%       200.000000        77.000000      1.139000e+04
# 75%       200.000000       371.000000      4.851200e+04
# max       502.000000    503770.000000      6.044766e+06

# %% [markdown]
# ##### Visualização dos Dados
#
# Para identificar visualmente o aumento repentino de tráfego, vamos criar gráficos de linha para a quantidade de requisições ao longo do tempo.

# %%
# Converter a coluna 'hora' para datetime
dados_sem_ataque['hora'] = pd.to_datetime(dados_sem_ataque['hora'])
dados_com_ataque['hora'] = pd.to_datetime(dados_com_ataque['hora'])

# Contar o número de requisições a cada 5 segundos
dados_sem_ataque['contagem'] = 1
dados_com_ataque['contagem'] = 1

# Resumir os dados por intervalo de 5 segundos
dados_sem_ataque_resumido = dados_sem_ataque.set_index('hora').resample('5S').sum()
dados_com_ataque_resumido = dados_com_ataque.set_index('hora').resample('5S').sum()

# Plotar os gráficos
plt.figure(figsize=(15, 6))
plt.plot(dados_sem_ataque_resumido.index, dados_sem_ataque_resumido['contagem'], label='Sem ataque')
plt.plot(dados_com_ataque_resumido.index, dados_com_ataque_resumido['contagem'], label='Com ataque')
plt.xlabel('Hora')
plt.ylabel('Número de Requisições')
plt.title('Número de Requisições ao Longo do Tempo')
plt.legend()
plt.show()

# %%
# Plotar os gráficos
plt.figure(figsize=(15, 6))
plt.plot(dados_sem_ataque_resumido.index, dados_sem_ataque_resumido['tamanho_request'], label='Sem ataque')
plt.plot(dados_com_ataque_resumido.index, dados_com_ataque_resumido['tamanho_request'], label='Com ataque')
plt.xlabel('Hora')
plt.ylabel('Tamanho das Requisições')
plt.title('Tamanho das Requisições ao Longo do Tempo')
plt.legend()
plt.show()

# %%
# Plotar os gráficos
plt.figure(figsize=(15, 6))
plt.hist(dados_sem_ataque_resumido['tamanho_request'], label='Sem ataque')
plt.title('Distribuição dos dados de acordo com as requisições')
plt.legend()
plt.show()

# %%
# Plotar os gráficos
plt.figure(figsize=(15, 6))
plt.hist(dados_com_ataque_resumido['tamanho_request'], label='Com ataque')
plt.title('Distribuição dos dados de acordo com as requisições')
plt.legend()
plt.show()

# %% [markdown]
# #### 2. Identificação de Padrões de Ataque

# %% [markdown]
# ##### Análise de Características
#
# Vamos explorar diferentes características dos logs (como IP, user agent, URI, etc.) para identificar padrões comuns durante o ataque.

# %%
# Análise de IPs únicos
ips_sem_ataque = dados_sem_ataque['ip'].nunique()
ips_com_ataque = dados_com_ataque['ip'].nunique()

print(f"Número de IPs únicos sem ataque: {ips_sem_ataque}")
print(f"Número de IPs únicos com ataque: {ips_com_ataque}")

# Análise de user agents únicos
user_agents_sem_ataque = dados_sem_ataque['useragent'].nunique()
user_agents_com_ataque = dados_com_ataque['useragent'].nunique()

print(f"Número de user agents únicos sem ataque: {user_agents_sem_ataque}")
print(f"Número de user agents únicos com ataque: {user_agents_com_ataque}")
# Out:
# Número de IPs únicos sem ataque: 17010
# Número de IPs únicos com ataque: 10122
# Número de user agents únicos sem ataque: 287
# Número de user agents únicos com ataque: 1868

# %% [markdown]
# #### 3. Preparação dos Dados
#
# Para desenvolver um modelo de classificação, precisamos preparar os dados. Vamos codificar as variáveis categóricas e dividir os dados em conjuntos de treinamento e teste.

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# Seleção de atributos
atributos = ['ip', 'metodo', 'protocolo', 'hostname', 'uri', 'querystring', 'status_code', 'useragent', 'organizacao', 'pais', 'cidade']
X = dados_com_ataque[atributos]

# Codificação das variáveis categóricas
label_encoders = {}
for column in X.columns:
    label_encoders[column] = LabelEncoder()
    X[column] = label_encoders[column].fit_transform(X[column])

# Criação da variável alvo (1 para ataque, 0 para tráfego normal), pensando numa quantidade média sem ataque, o que estiver acima da média é suspeito de ataque.
y = (dados_com_ataque['tamanho_request'] >= dados_sem_ataque['tamanho_request'].mean()).astype(int)

# %%
y.value_counts()
# Out:
# tamanho_request
# 0    347442
# 1      1422
# Name: count, dtype: int64

# %%
# Divisão dos dados em treinamento e teste de forma estratificada
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, stratify=y, random_state=42)

# %%
print(X_train.shape,  y_train.shape)
print(X_test.shape,  y_test.shape)
# Out:
# (244204, 11) (244204,)
# (104660, 11) (104660,)

# %% [markdown]
# #### 4. Treinamento do Modelo
#
# Vamos treinar um modelo de classificação usando uma árvore de decisão.

# %%
from sklearn.metrics import accuracy_score, f1_score, roc_curve, roc_auc_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, confusion_matrix

# %%
# Treinamento do modelo baseado em Random Forest
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

# Avaliação do modelo
y_pred = rf.predict(X_test)

# Obter as probabilidades das classes
y_prob = rf.predict_proba(X_test)[:, 1]

print(f"Acurácia......: {round(accuracy_score(y_test, y_pred), 4)*100}")
print(f"F1 score......: {round(f1_score(y_test, y_pred), 4)*100}")
print()
print("Resultados por classes")
print()
print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

# Calcular a curva ROC
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = roc_auc_score(y_test, y_prob)

# Plotar a curva ROC
plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (area = {roc_auc:.2f})')
plt.plot([0, 1], [0, 1], color='red', linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver Operating Characteristic (ROC) Curve')
plt.legend(loc='lower right')
plt.show()
# Out:
# Acurácia......: 99.97
# F1 score......: 96.12
#
# Resultados por classes
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00    104233
#            1       1.00      0.93      0.96       427
#
#     accuracy                           1.00    104660
#    macro avg       1.00      0.96      0.98    104660
# weighted avg       1.00      1.00      1.00    104660
#
# [[104232      1]
#  [    31    396]]

# %% [markdown]
# #### 5. Validação e Conclusão

# %% [markdown]
# ##### Conclusão
#
# Neste projeto, realizamos uma análise detalhada dos logs de servidor para identificar e mitigar um ataque DDoS. Utilizamos técnicas de análise exploratória para identificar padrões nos dados e desenvolvemos um modelo de classificação para diferenciar requisições legítimas de maliciosas.
#
# Apliquei o algoritmo Random Forest por já tê-lo utilizado em problemas de classificação e saber que ele se sai bem. De modo geral, o modelo teve ótima acurácia, mesmo lidando com dados desbalanceados.
#
# ##### Descobertas
# - Identificamos um aumento súbito no número de requisições durante o período de ataque.
# - Observamos padrões específicos em características como IPs e user agents que ajudaram na detecção do ataque.
#
# ##### Próximos Passos
# - Explorar técnicas de machine learning mais avançadas para melhorar a precisão do modelo.
# - Implementar uma solução em tempo real para detecção e mitigação de ataques DDoS.
#
# A abordagem apresentada demonstra como utilizar dados de logs de servidor para identificar e mitigar ataques DDoS de maneira eficaz, garantindo a segurança e disponibilidade das aplicações web.
#
# Obs.: Ainda é necessário mais pesquisas para entender melhor o problema.
